# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.0/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Out:
# Archive:  /content/drive/MyDrive/Mama.zip
# replace /content/drive/MyDrive/Mama/Mama/train/images/1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/drive/MyDrive/Mama/Mama/train/images/1.jpg
#   inflating: /content/drive/MyDrive/Mama/Mama/train/images/10.jpg
#   inflating: /content/drive/MyDrive/Mama/Mama/train/images/11.jpg
#   inflating: /content/drive/MyDrive/Mama/Mama/train/images/12.jpg
#   inflating: /content/drive/MyDrive/Mama/Mama/train/images/14.jpg
#   inflating: /content/drive/MyDrive/Mama/Mama/train/images/16.jpg
#   inflating: /content/drive/MyDrive/Mama/Mama/train/images/17.jpg
#   inflating: /content/drive/MyDrive/Mama/Mama/train/images/18.jpg
#   inflating: /content/drive/MyDrive/Mama/Mama/train/images/19.jpg
#   inflating: /content/drive/MyDrive/Mama/Mama/train/images/2.jpg
#   inflating: /content/drive/MyDrive/Mama/Mama/train/images/20.jpg
#   inflating: /content/drive/MyDrive/Mama/Mama/train/images/21.jpg
# ...

# %%
# !yolo train model=yolov8x.pt data=data.yml epochs=50 imgsz=640
# Out:
# ...
# 100% 131M/131M [00:00<00:00, 374MB/s]
# Ultralytics YOLOv8.2.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !display.Image(filename='/content/runs/detect/train/train_batch682.jpg', width=600)
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `filename='/content/runs/detect/train/train_batch682.jpg','
# /bin/bash: -c: line 1: `display.Image(filename='/content/runs/detect/train/train_batch682.jpg', width=600)'

# %%
# !yolo train model=yolov8n.pt data=/content/data.yml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.2.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo train model=yolov8m.pt data=data.yml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.2.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo train model=yolov8s.pt data=/content/data.yml epochs=50 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 167MB/s]
# Ultralytics YOLOv8.2.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo train model=yolov8l.pt data=/content/data.yml epochs=50 imgsz=640
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 235MB/s]
# Ultralytics YOLOv8.2.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Ultralytics YOLOv8.2.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 165k/165k [00:00<00:00, 10.3MB/s]
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 114.8ms
# Speed: 3.3ms preprocess, 114.8ms inference, 1831.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
